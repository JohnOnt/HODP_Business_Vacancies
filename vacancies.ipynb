# %%
import pandas as pd
import numpy as np

# %%
vacancies = pd.read_csv('Retail_Vacant_Storefronts_December_2020.csv')
businesses = pd.read_csv('Open_and_Closed_Businesses_During_Covid-19_Pandemic.csv')

# %%
vacancies.head()
# Out:
#   Commercial District               Address       City          State  \
# 0   Smaller Districts      123 River Street  Cambridge  Massachusetts
# 1      Kendall Square    One Kendall Square  Cambridge  Massachusetts
# 2  Fresh Pond-Alewife       93 Blanchard Rd  Cambridge  Massachusetts
# 3        Inman Square  168 Hampshire Street  Cambridge  Massachusetts
# 4      East Cambridge  149 Cambridge Street  Cambridge  Massachusetts
#
#    Zip Code  Square Footage Length of Vacancy  \
# 0      2139           900.0   5 years or more
# 1      2139             NaN       6-10 months
# 2      2138             NaN       6-10 months
# 3      2139           840.0   5 years or more
# 4      2141             NaN       6-10 months
#
#                         Ownership Type Former Tenant/Current Business  \
# 0                           Individual                     River Gods
# 1  Real Estate Investment Trust (REIT)              Flat Top Johnny’s
# ...

# %%
print(vacancies['Commercial District'].unique())
print(vacancies['Length of Vacancy'].unique())
# Out:
# ['Smaller Districts' 'Kendall Square' 'Fresh Pond-Alewife' 'Inman Square'
#  'East Cambridge' 'North Massachusetts Ave.' 'Harvard Square'
#  'Porter Sq-Lower Massachusetts Ave.' 'Central Square' 'Observatory Hill']
# ['5 years or more' '6-10 months' '1-2 years' '2-5 years' nan]

# %%
vacancies.loc[vacancies['Commercial District'] == 'Central Square']
# Out:
#     Commercial District                    Address       City          State  \
# 20       Central Square          93 Windsor Street  Cambridge  Massachusetts
# 22       Central Square     114 Bishop Allen Drive  Cambridge  Massachusetts
# 31       Central Square         21 Prospect Street  Cambridge  Massachusetts
# 34       Central Square   425 Massachusetts Avenue  Cambridge  Massachusetts
# 41       Central Square            795 Main Street  Cambridge  Massachusetts
# 48       Central Square      605 Massachusetts Ave  Cambridge  Massachusetts
# 53       Central Square     645 Massachusetts Ave.  Cambridge  Massachusetts
# 67       Central Square   738 Massachusetts Avenue  Cambridge  Massachusetts
# 73       Central Square  571-577 Massachusetts Ave  Cambridge  Massachusetts
# 74       Central Square   596 Massachusetts Avenue  Cambridge  Massachusetts
# 84       Central Square             8 Essex Street  Cambridge  Massachusetts
# ...

# %%
businesses.head()
# Out:
#                     Name Address Storefront Sales Status  \
# 0      1369 Coffee House     NaN                    Open
# 1      1369 Coffee House     NaN                    Open
# 2          2 4-1 Optical     NaN                    Open
# 3  5th Street Laundromat     NaN                    Open
# 4               7-Eleven     NaN                    Open
#
#                         Sales Options Grocery Sales                   Phone  \
# 0                  Delivery, Take Out           yes            757 Mass Ave
# 1  Delivery, Take Out, Outdoor Dining           NaN   1369 Cambridge Street
# 2                                 NaN           NaN  1128 Massachusetts Ave
# 3                                 NaN           NaN           58 5th Street
# 4                                 NaN           NaN  All locations are open
#
#   Website                                   Facebook  \
# 0     NaN  https://www.facebook.com/1369Coffeehouse/
# 1     NaN  https://www.facebook.com/1369Coffeehouse/
# ...

# %%
businesses.shape
# Out:
# (863, 11)
